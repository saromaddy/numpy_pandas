# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.random.normal(loc = 60, scale = 3, size =5000) #data_generation, loc is mean = 60

# %%
x
# Out:
# array([63.49036637, 52.99999752, 60.85894473, ..., 58.39075812,
#        66.98611627, 60.22785685])

# %%
plt.plot(x)

# %%
x.min(),x.max()
# Out:
# (46.484751430389174, 71.1990506867771)

# %%
plt.hist(x, bins = 20)
#plt.show()
# Out:
# (array([  1.,   1.,   3.,  10.,  26.,  76., 159., 297., 500., 699., 800.,
#         768., 654., 474., 285., 156.,  61.,  21.,   6.,   3.]),
#  array([46.48475143, 47.72046639, 48.95618136, 50.19189632, 51.42761128,
#         52.66332624, 53.89904121, 55.13475617, 56.37047113, 57.6061861 ,
#         58.84190106, 60.07761602, 61.31333098, 62.54904595, 63.78476091,
#         65.02047587, 66.25619084, 67.4919058 , 68.72762076, 69.96333572,
#         71.19905069]),
#  <BarContainer object of 20 artists>)

# %%
sns.histplot(x,kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.kdeplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
115/85
# Out:
# 1.3529411764705883

# %%
85/115
# Out:
# 0.7391304347826086

# %%
x = np.random.binomial(n=115,p=0.74, size = 100000)
sns.kdeplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
# saravana - Chisquared
